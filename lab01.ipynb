# %%
import pandas as pd
import numpy as np

# %%
dictFilmes = {
    'AVATAR': 2.847,
    'VINGADORES: ULTIMATO': 2.797,
    'AVATAR: O CAMINHO DA ÁGUA': 2.247,
    'TITANIC': 2.245,
    'STAR WARS: O DESPERTAR DA FORÇA': 2.069,
    'VINGADORES: GUERRA INFINITA': 2.048,
    'HOMEM-ARANHA: SEM VOLTA PARA CASA': 1.832,
    'JURASSIC WORLD: O MUNDO DOS DINOSSAUROS': 1.670,
    'O REI LEÃO': 1.662,
    'OS VINGADORES': 1.518
}

# %%
serie1 = pd.Series(dictFilmes)
serie1
# Out:
# AVATAR                                     2.847
# VINGADORES: ULTIMATO                       2.797
# AVATAR: O CAMINHO DA ÁGUA                  2.247
# TITANIC                                    2.245
# STAR WARS: O DESPERTAR DA FORÇA            2.069
# VINGADORES: GUERRA INFINITA                2.048
# HOMEM-ARANHA: SEM VOLTA PARA CASA          1.832
# JURASSIC WORLD: O MUNDO DOS DINOSSAUROS    1.670
# O REI LEÃO                                 1.662
# OS VINGADORES                              1.518
# dtype: float64

# %%
filmes = ['AVATAR', 'VINGADORES: ULTIMATO', 'AVATAR: O CAMINHO DA ÁGUA', 'TITANIC', 'STAR WARS: O DESPERTAR DA FORÇA', 'VINGADORES: GUERRA INFINITA', 'HOMEM-ARANHA: SEM VOLTA PARA CASA', 'JURASSIC WORLD: O MUNDO DOS DINOSSAUROS', 'O REI LEÃO', 'OS VINGADORES']

# %%
bilhoes = [2.847, 2.797, 2.247, 2.245, 2.069, 2.048, 1.832, 1.670, 1.662, 1.518]

# %%
serie2 = pd.Series (bilhoes, index=filmes)
serie2
# Out:
# AVATAR                                     2.847
# VINGADORES: ULTIMATO                       2.797
# AVATAR: O CAMINHO DA ÁGUA                  2.247
# TITANIC                                    2.245
# STAR WARS: O DESPERTAR DA FORÇA            2.069
# VINGADORES: GUERRA INFINITA                2.048
# HOMEM-ARANHA: SEM VOLTA PARA CASA          1.832
# JURASSIC WORLD: O MUNDO DOS DINOSSAUROS    1.670
# O REI LEÃO                                 1.662
# OS VINGADORES                              1.518
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
serie2.plot()
# Out:
# <Axes: >

# %% [markdown]
# Este gráfico mostra a lista dos filmes com as maiores bilheterias da história!
